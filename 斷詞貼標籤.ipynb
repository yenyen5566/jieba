# %%
# !pip install jieba
# Out:
# ...
#     100% |████████████████████████████████| 7.4MB 228kB/s ta 0:00:011
# ...
#   Running setup.py bdist_wheel for jieba ... done
#   Stored in directory: /home/yen/.cache/pip/wheels/fd/8c/07/e495d158d91e11f50c829520f77d20d1f408f18a13cdb15d02
# Successfully built jieba
# ...

# %% [markdown]
# ## python 連接mysql

# %%
import pymysql as mysql

db = mysql.connect(host="10.120.37.114", user="yen", passwd="1234", db="house")

cursor = db.cursor()

cursor.execute("SET CHARACTER_SET_RESULTS=UTF8")

cursor.execute("SELECT url,title,label2 from rental where label2 is null;")
result = cursor.fetchall()

for record in result:
    print(record)
# Out:
# ('http://rent.sinyi.com.tw/itemDetail.php?s=1&itemid=C155879', 'è¡\x8cå¤©å®®æ\x8d·é\x81\x8båº\x97è¾¦â\x85\xa0', None)
# ('http://rent.sinyi.com.tw/itemDetail.php?s=1&itemid=1293095CT', 'ç¦\x8få\x9c\x8bè¡\x97å\x88\x86å¥\x97 â\x96\x8eè¿\x91å¤§æ½¤ç\x99¼', None)
# ('http://rent.sinyi.com.tw/itemDetail.php?s=1&itemid=239217', 'COSTCOå\x84ªè³ªç¾\x8e3+1æ\x88¿å\x90«å¹³è»\x8a', None)
# ('http://rent.sinyi.com.tw/itemDetail.php?s=1&itemid=239218', 'é£¯åº\x97å¼\x8fæ\x99¯è§\x80æ\x96°ç\x8d¨ç«\x8bå¥\x97æ\x88¿', None)
# ('http://rent.sinyi.com.tw/itemDetail.php?s=1&itemid=239231', 'å¤§åº\x92å\x84ªè³ªä¸\x89æ\x88¿~é\x99\x84å¹³é\x9d¢è»\x8aä½\x8d', None)
# ('http://rent.sinyi.com.tw/itemDetail.php?s=1&itemid=239240', 'Fä¸\x89æ\x80§æ©\x8bä¸\x80æ¨\x93 å\xad\x9dè¦ªæ\x88¿ å®¤å\x85§è»\x8aåº«', None)
# ('http://rent.sinyi.com.tw/itemDetail.php?s=1&itemid=239239', 'BF è¿\x91ç«¹ç§\x91é\x80\x8få¤©å\x86·æ°£å\x85\xadæ\x88¿~é\x99\x84é\x9b\x99è»\x8aä½\x8d', None)
# ...

# %% [markdown]
# ## 建立字典

# %%
import csv  #載入專門開csv檔案的套件
import jieba
import codecs
import jieba.analyse  #載入能萃取出文章中關鍵詞的功能
jieba.set_dictionary('dict.txt')

factory = []                                    
factories = open('factory.txt','r').readlines()
for f in factories:
    factory.append(f.strip())
    
car = []                                    
cars = open('car.txt','r').readlines()
for c in cars:
    car.append(c.strip())
    
warehouse = []                                    
warehouses = open('warehouse.txt','r').readlines()
for w in warehouses:
    warehouse.append(w.strip())
    
business = []                                    
businesses = open('business.txt','r').readlines()
for b in businesses:
    business.append(b.strip())
    
store = []                                    
stores = open('store.txt','r').readlines()
for st in stores:
    store.append(st.strip())
    
house = []                                    
houses = open('house.txt','r').readlines()
for h in houses:
    house.append(h.strip())
    
    
tao = []                                    
taos = open('tao.txt','r').readlines()
for t in taos:
    tao.append(t.strip())
    
ya = []                                    
yas = open('ya.txt','r').readlines()
for y in yas:
    ya.append(y.strip())

stop = []                                    
stops = open('stop.txt','r').readlines()
for s in stops:
    stop.append(s.strip())

# %%
print(car)
# Out:
# ['車位', '車']

# %%
content = []   #裝最後分詞完的結果
contents = open('1.csv','r',encoding='utf-8', errors='ignore').readlines()    #開啟檔案
for row in csv.DictReader(contents):    #csv.DictReader函式可依欄位名開啟特定欄位
    words = jieba.cut(row['title'].replace(' ',''), cut_all=False)    #只讓'name'此欄位下的內容做斷詞
    temp = []    #每個詞斷出的結果
    category = []
    for word in words:
        if word not in stop:
            temp.append(word)   
            

        if word in tao :         
            category.append('t')
            break
        if word in ya :         
            category.append('y')
            break 
        if word in factory :          
            category.append('f')
            break
        if word in warehouse :          
            category.append('w')
            break
        if word in business :       
            category.append('b')
            break
        if word in store :         
            category.append('s')
            break
        if word in house :         
            category.append('h')
            break
        if word in car :         
            category.append('c')
            break

    print(category)
    
    if category:        #如果category不為空字串的話 （空字串在python if條件式下為false）
        content.append(temp+category)
        
    else:
        content.append(temp)
   
    
# content
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
content = []   #裝最後分詞完的結果
contents = open('1.csv','r',encoding='utf-8', errors='ignore').readlines()    #開啟檔案
for row in csv.DictReader(contents):    #csv.DictReader函式可依欄位名開啟特定欄位
    words = jieba.cut(row['title'].replace(' ',''), cut_all=False)    #只讓'name'此欄位下的內容做斷詞
    temp = []    #每個詞斷出的結果
    for word in words:
        if word not in stop:
            temp.append(word)   
            

    
    if category:        #如果category不為空字串的話 （空字串在python if條件式下為false）
        content.append(temp+category)
        
    else:
        content.append(temp)
   
    
# content
